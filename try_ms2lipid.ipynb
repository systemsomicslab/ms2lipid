# %%
pip install ms2lipid

# %%
import ms2lipid

# %%
import pandas as pd
pd.read_csv("https://github.com/systemsomicslab/ms2lipid/raw/main/tests/test_data_csv_neg.csv").head()
# Out:
#    sampleid                                       MSMSspectrum  \
# 0       319  78.95742:90 168.03941:24 225.18069:24 255.2411...
# 1       168  209.18742:10 237.22816:36 263.24307:12 268.248...
# 2        78  78.95427:12 131.08197:5 140.00705:12 184.8981:...
# 3       580  78.95772:93 96.96303:24 107.08226:12 134.98502...
# 4       424  78.71752:12 78.95817:510 96.96765:48 97.00733:...
#
#    Annotationtag(VS1.0)  AverageRt(min)  AverageMz  ReferenceRT  Referencemz  \
# 0                   310           9.010  746.52966         8.92    746.53412
# 1                   310          13.232  724.64954        12.97    724.64612
# 2                   310           6.137  526.29022         6.01    526.29388
# 3                   310           8.319  881.52118         8.10    881.51862
# 4                   410           8.955  834.52863         8.36    834.52911
#
#     Adducttype Ontology                      Metabolitename  AlignmentID  \
# ...

# %%
predicted_result_df = ms2lipid.predclass("https://github.com/systemsomicslab/ms2lipid/raw/main/tests/test_data_csv_neg.csv", "negative", "MSMSspectrum", "AverageMz")
# Out:
# Temporary directory created: /tmp/tmpsznbx_5g
# ion mode: negative
# /usr/local/lib/python3.10/dist-packages/ms2lipid/ms2lipid.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_wide_spct = df_wide_spct.fillna(0)
# /usr/local/lib/python3.10/dist-packages/ms2lipid/ms2lipid.py:78: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_wide_neuloss = df_wide_neuloss.fillna(0)
# 1/1 [==============================] - 0s 98ms/step

# %%
predicted_result_df
# Out:
#                                          ms2spectrum  precursormz  \
# 0  78.95742:90 168.03941:24 225.18069:24 255.2411...    746.52966
# 1  209.18742:10 237.22816:36 263.24307:12 268.248...    724.64954
# 2  78.95427:12 131.08197:5 140.00705:12 184.8981:...    526.29022
# 3  78.95772:93 96.96303:24 107.08226:12 134.98502...    881.52118
# 4  78.71752:12 78.95817:510 96.96765:48 97.00733:...    834.52863
# 5  78.95715:24 96.96958:12 152.99417:142 170.9963...    854.49756
# 6  196.03436:12 227.2028:65 253.21915:24 278.3587...    686.47351
# 7  152.99162:85 171.00291:48 209.0099:12 214.0510...    775.55054
# 8  78.93581:12 78.957:325 87.92805:10 96.96802:60...    861.55408
# 9  245.82442:10 281.24854:514 282.24973:24 387.32...    950.68317
#
#   predict_1class predict_candidateclass
# 0        EtherPS          EtherPS:99.6%
# 1         Cer_AS           Cer_AS:99.8%
# 2            LPE             LPE:100.0%
# 3             PI              PI:100.0%
# ...

# %%
ms2lipid.prediction_summary(predicted_result_df, "/content/test_data_csv_neg.csv", class_name="Ontology")
# Out:
# pred_1class_eval: 10
# pred_cand_eval: 10
# mispred: 0
# pred 1class correct ratio: 1.0
# pred candidate correct ratio: 1.0
# mispred ratio: 0.0
